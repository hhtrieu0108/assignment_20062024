# %%
import pandas as pd
from sqlalchemy import create_engine
df = pd.read_csv("bank_transactions.csv")

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'], format='%d/%m/%y').dt.date

# %%
df['CustomerDOB'] = df['CustomerDOB'].apply(lambda x: pd.to_datetime(x,format='%d/%m/%Y').date() if isinstance(x,str) and len(x.split('/')[2]) == 4 else x )

# %%
df['CustomerDOB'] = df['CustomerDOB'].apply(lambda x: pd.to_datetime(x,format='%d/%m/%y').date() if isinstance(x,str) and len(x.split('/')[2]) < 3 else x )

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053  1994-01-10          F     JAMSHEDPUR
# 1                  T2   C2142763  2057-04-04          M        JHAJJAR
# 2                  T3   C4417068  1996-11-26          F         MUMBAI
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229  1990-04-08          M      NEW DELHI
# 1048563      T1048564   C6459278  1992-02-20          M         NASHIK
# 1048564      T1048565   C6412354  1989-05-18          M      HYDERABAD
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-03-05          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df.dtypes
# Out:
# TransactionID               object
# CustomerID                  object
# CustomerDOB                 object
# CustGender                  object
# CustLocation                object
# CustAccountBalance         float64
# TransactionDate             object
# TransactionTime              int64
# TransactionAmount (INR)    float64
# dtype: object

# %%
engine = create_engine("postgresql://username:password@host:5432/database")
df.to_sql("banking_transaction",engine,if_exists='replace',index=False)
# Out:
# 567
